# %%
import pandas as pd,numpy as np
df=pd.read_csv("popularity.csv")

# %%
df.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...  \
# ...

# %%
df.shape
# Out:
# (39644, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39644 entries, 0 to 39643
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   url                             39644 non-null  object
#  1    timedelta                      39644 non-null  float64
#  2    n_tokens_title                 39644 non-null  float64
#  3    n_tokens_content               39644 non-null  float64
#  4    n_unique_tokens                39644 non-null  float64
#  5    n_non_stop_words               39644 non-null  float64
#  6    n_non_stop_unique_tokens       39644 non-null  float64
#  7    num_hrefs                      39644 non-null  float64
#  8    num_self_hrefs                 39644 non-null  float64
#  9    num_imgs                       39644 non-null  float64
#  10   num_videos                     39644 non-null  float64
#  11   average_token_length           39644 non-null  float64
# ...

# %%
df[' shares']
# Out:
# 0         593
# 1         711
# 2        1500
# 3        1200
# 4         505
#          ...
# 39639    1800
# 39640    1900
# 39641    1900
# 39642    1100
# 39643    1300
# Name:  shares, Length: 39644, dtype: int64

# %%
df[' shares'].value_counts()
# Out:
# 1100      2308
# 1200      2018
# 1300      1740
# 1400      1592
# 1500      1323
#           ...
# 197600       1
# 310800       1
# 92           1
# 57800        1
# 82200        1
# Name:  shares, Length: 1454, dtype: int64

# %%
df[' shares'].value_counts().plot.box()
# Out:
# <AxesSubplot:>

# %%
df[' shares'].mean()
# Out:
# 3395.3801836343455

# %%
df[' shares'].median()
# Out:
# 1400.0

# %%
df[' shares'].max()
# Out:
# 843300

# %%
df[' shares'].quantile(.78,interpolation='linear')
# Out:
# 3100.0

# %%
df[' shares'].percentile(0.78)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-0038c64023e6> in <module>
# ----> 1 df[' shares'].percentile(0.78)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'percentile'

# %%
np.percentile(df[' shares'],0.78)
# Out:
# 341.0

# %%
df[' shares'].quantile(.95,interpolation='linear')
# Out:
# 10800.0

# %%
df[df[' shares']>10800]
# Out:
#                                                      url   timedelta  \
# 16             http://mashable.com/2013/01/07/echo-game/       731.0
# 19     http://mashable.com/2013/01/07/felt-audio-puls...       731.0
# 129    http://mashable.com/2013/01/09/hobbit-misty-mo...       729.0
# 174    http://mashable.com/2013/01/09/warner-bros-twe...       729.0
# 176    http://mashable.com/2013/01/09/will-ferrell-fi...       729.0
# ...                                                  ...         ...
# 39500  http://mashable.com/2014/12/24/christmas-down-...        11.0
# 39503  http://mashable.com/2014/12/24/doctor-who-last...        11.0
# 39537    http://mashable.com/2014/12/24/ubert-price-nyc/        10.0
# 39542  http://mashable.com/2014/12/25/16-extreme-santas/        10.0
# 39621  http://mashable.com/2014/12/26/ukraine-prisone...         9.0
#
#         n_tokens_title   n_tokens_content   n_unique_tokens  \
# 16                 8.0             1118.0          0.512397
# ...

# %%
df1=df[df[' shares']<=10800]

# %%
df1.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...  \
# ...

# %%
df1.shape
# Out:
# (37663, 61)

# %%
df1[' shares'].mean()
# Out:
# 2074.334386533202

# %%
df1[' shares'].std()
# Out:
# 1871.8141388442016

# %%
df1[' shares'].describe()
# Out:
# count    37663.000000
# mean      2074.334387
# std       1871.814139
# min          1.000000
# 25%        927.000000
# 50%       1400.000000
# 75%       2400.000000
# max      10800.000000
# Name:  shares, dtype: float64
