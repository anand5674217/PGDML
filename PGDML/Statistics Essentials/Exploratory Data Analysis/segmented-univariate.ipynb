# %%
import pandas as pd, numpy as np

# %%
df=pd.read_csv("EDA_nas.csv")

# %%
df.head()
# Out:
#          STUID        State  District Gender       Age  Category  \
# 0  26011001001  Maharashtra         1   Girl  13 years       3.0
# 1  26011001002  Maharashtra         1   Girl  15 years       3.0
# 2  26011001003  Maharashtra         1   Girl  14 years       3.0
# 3  26011001004  Maharashtra         1    Boy  13 years       3.0
# 4  26011001005  Maharashtra         1   Girl  14 years       3.0
#
#    Same.language    Siblings Handicap      Father.edu  ...  \
# 0            2.0   1 sibling       No      Illiterate  ...
# 1            2.0  3 siblings       No             NaN  ...
# 2            2.0  3 siblings       No  Degree & above  ...
# 3            2.0  3 siblings       No       Secondary  ...
# 4            2.0  2 siblings       No         Primary  ...
#
#   Express.science.views     Watch.TV Read.magazine   Read.a.book   Play.games  \
# 0                 Agree    Every day         Never  Once a month  Once a week
# ...

# %%
df.groupby('Watch.TV')['Science..'].mean()
# Out:
# Watch.TV
# Every day       36.357915
# Never           35.638589
# Once a month    36.786127
# Once a week     36.467112
# Name: Science.., dtype: float64

# %%
df1=df.groupby(['Watch.TV'])

# %%
# Out:
#            STUID        State  District Gender       Age  Category  \
# 0    26011001001  Maharashtra         1   Girl  13 years       3.0
# 1    26011001002  Maharashtra         1   Girl  15 years       3.0
# 2    26011001003  Maharashtra         1   Girl  14 years       3.0
# 3    26011001004  Maharashtra         1    Boy  13 years       3.0
# 4    26011001005  Maharashtra         1   Girl  14 years       3.0
# 5    26011001006  Maharashtra         1   Girl  13 years       3.0
# 6    26011001007  Maharashtra         1   Girl  14 years       1.0
# 34   26011002015  Maharashtra         1    Boy  14 years       3.0
# 35   26011002016  Maharashtra         1    Boy  13 years       4.0
# 36   26011002017  Maharashtra         1    Boy  13 years       1.0
# 42   26011002023  Maharashtra         1    Boy  14 years       3.0
# 43   26011002024  Maharashtra         1    Boy  14 years       1.0
# 44   26011002025  Maharashtra         1    Boy  14 years       4.0
# ...

# %%
df.head()
# Out:
#          STUID        State  District Gender       Age  Category  \
# 0  26011001001  Maharashtra         1   Girl  13 years       3.0
# 1  26011001002  Maharashtra         1   Girl  15 years       3.0
# 2  26011001003  Maharashtra         1   Girl  14 years       3.0
# 3  26011001004  Maharashtra         1    Boy  13 years       3.0
# 4  26011001005  Maharashtra         1   Girl  14 years       3.0
#
#    Same.language    Siblings Handicap      Father.edu  ...  \
# 0            2.0   1 sibling       No      Illiterate  ...
# 1            2.0  3 siblings       No             NaN  ...
# 2            2.0  3 siblings       No  Degree & above  ...
# 3            2.0  3 siblings       No       Secondary  ...
# 4            2.0  2 siblings       No         Primary  ...
#
#   Express.science.views     Watch.TV Read.magazine   Read.a.book   Play.games  \
# 0                 Agree    Every day         Never  Once a month  Once a week
# ...

# %%
df.groupby('Father.edu')['Maths..'].mean()
# Out:
# Father.edu
# Degree & above    34.879193
# Illiterate        29.126754
# Primary           32.561137
# Secondary         32.230393
# Sr secondary      32.493415
# Name: Maths.., dtype: float64

# %%
df.groupby('Play.games')['Reading..'].mean()
# Out:
# Play.games
# Every day       54.780136
# Never           49.107484
# Once a month    51.951193
# Once a week     59.627034
# Name: Reading.., dtype: float64

# %%
df.head()
# Out:
#          STUID        State  District Gender       Age  Category  \
# 0  26011001001  Maharashtra         1   Girl  13 years       3.0
# 1  26011001002  Maharashtra         1   Girl  15 years       3.0
# 2  26011001003  Maharashtra         1   Girl  14 years       3.0
# 3  26011001004  Maharashtra         1    Boy  13 years       3.0
# 4  26011001005  Maharashtra         1   Girl  14 years       3.0
#
#    Same.language    Siblings Handicap      Father.edu  ...  \
# 0            2.0   1 sibling       No      Illiterate  ...
# 1            2.0  3 siblings       No             NaN  ...
# 2            2.0  3 siblings       No  Degree & above  ...
# 3            2.0  3 siblings       No       Secondary  ...
# 4            2.0  2 siblings       No         Primary  ...
#
#   Express.science.views     Watch.TV Read.magazine   Read.a.book   Play.games  \
# 0                 Agree    Every day         Never  Once a month  Once a week
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8801 entries, 0 to 8800
# Data columns (total 64 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STUID                   8801 non-null   int64
#  1   State                   8801 non-null   object
#  2   District                8801 non-null   int64
#  3   Gender                  8799 non-null   object
#  4   Age                     8569 non-null   object
#  5   Category                8232 non-null   float64
#  6   Same.language           8572 non-null   float64
#  7   Siblings                8801 non-null   object
#  8   Handicap                8304 non-null   object
#  9   Father.edu              8147 non-null   object
#  10  Mother.edu              7950 non-null   object
#  11  Father.occupation       7761 non-null   object
#  12  Mother.occupation       6626 non-null   object
#  13  Below.poverty           7347 non-null   object
# ...

# %%
df.State.value_counts()
# Out:
# Maharashtra    8801
# Name: State, dtype: int64

# %%
df.shape
# Out:
# (8801, 64)

# %%
df.groupby('Solve.Maths')['Maths..'].mean()
# Out:
# Solve.Maths
# Agree       32.800920
# Disagree    30.841321
# Neither     29.384388
# Name: Maths.., dtype: float64

# %%
df.groupby('Solve.Maths')['Maths..'].plot.box()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-6e5b986646ff> in <module>
# ----> 1 df.groupby('Solve.Maths')['Maths..'].plot.box()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in attr(*args, **kwargs)
#     453                 return getattr(self.plot, name)(*args, **kwargs)
#     454
# --> 455             return self._groupby.apply(f)
#     456
#     457         return attr
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in apply(self, func, *args, **kwargs)
#     224     )
#     225     def apply(self, func, *args, **kwargs):
# --> 226         return super().apply(func, *args, **kwargs)
#     227
#     228     @doc(
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     857         with option_context("mode.chained_assignment", None):
#     858             try:
# ...

# %%
import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-86e89bd44552> in <module>
# ----> 1 import plotly.express as px
#
# ModuleNotFoundError: No module named 'plotly'
