# %%
import pandas as pd

# %%
df=pd.read_csv("../../../Inferential Statistics - Student Loan.csv")

# %%
df.head()
# Out:
#    Customer No.  Exposure at Default (in lakh Rs.) Recovery (%)  \
# 0             1                              11.50       20.00%
# 1             2                               0.24        5.10%
# 2             3                               0.04       24.86%
# 3             4                              13.81        2.29%
# 4             5                              19.84        3.47%
#
#    Probability of Default  Unnamed: 4  Unnamed: 5
# 0                  0.0070         NaN         NaN
# 1                  0.0033         NaN         NaN
# 2                  0.0022         NaN         NaN
# 3                  0.0066         NaN         NaN
# 4                  0.0020         NaN         NaN

# %%
df.columns
# Out:
# Index(['Customer No.', 'Exposure at Default (in lakh Rs.)', 'Recovery (%)',
#        'Probability of Default', 'Unnamed: 4', 'Unnamed: 5'],
#       dtype='object')

# %%
df['expected']=df['Probability of Default']*df['Exposure at Default (in lakh Rs.)']*(1-df['Recovery (%)'])

# %%
df['Recovery (%)']=df['Recovery (%)'].apply(lambda x: float(x[:-1])/100)

# %%
df
# Out:
#       Customer No.  Exposure at Default (in lakh Rs.)  Recovery (%)  \
# 0                1                              11.50        0.2000
# 1                2                               0.24        0.0510
# 2                3                               0.04        0.2486
# 3                4                              13.81        0.0229
# 4                5                              19.84        0.0347
# ...            ...                                ...           ...
# 9995          9996                              19.79        0.2019
# 9996          9997                              18.33        0.3838
# 9997          9998                              10.83        0.2840
# 9998          9999                              24.29        0.3737
# 9999         10000                               0.03        0.2255
#
#       Probability of Default  Unnamed: 4  Unnamed: 5  expected
# 0                     0.0070         NaN         NaN  0.064400
# ...

# %%
df.expected.sum()
# Out:
# 493.39131440619997
