# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("loan.csv",engine='python')

# %%
df.shape
# Out:
# (39717, 111)

# %%
df.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
df.isnull().sum(axis=1)
# Out:
# 0        58
# 1        57
# 2        59
# 3        56
# 4        55
#          ..
# 39712    59
# 39713    59
# 39714    61
# 39715    61
# 39716    59
# Length: 39717, dtype: int64

# %%
df.sample(10)
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 586    1062293    1294356      25000        25000      25000.00000
# 14661   762415     962938      20000        20000      19750.00000
# 21799   638399     817775      19000        19000      16499.90668
# 17767   710269     903003       3200         3200       3200.00000
# 16900   723210     918120      20000        20000      19975.00000
# 2443   1036084    1265950      17000        17000      16500.00000
# 29181   525909     680428      12000        12000      11932.07277
# 14787   752905     952527      35000        35000      34975.00000
# 12696   791091     995353       7000         7000       7000.00000
# 20134   657244     840614      20000        20000      19500.00000
#
#              term int_rate  installment grade sub_grade  ...  \
# 586     36 months    9.91%       805.63     B        B1  ...
# 14661   36 months   13.49%       678.61     C        C2  ...
# ...

# %%
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
df.member_id.unique().size
# Out:
# 39717

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
df[['member_id']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   member_id  39717 non-null  int64
# dtypes: int64(1)
# memory usage: 310.4 KB

# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %%
df.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df.isnull().sum()==39717
# Out:
# id                                False
# member_id                         False
# loan_amnt                         False
# funded_amnt                       False
# funded_amnt_inv                   False
# term                              False
# int_rate                          False
# installment                       False
# grade                             False
# sub_grade                         False
# emp_title                         False
# emp_length                        False
# home_ownership                    False
# annual_inc                        False
# verification_status               False
# issue_d                           False
# loan_status                       False
# pymnt_plan                        False
# url                               False
# desc                              False
# purpose                           False
# title                             False
# zip_code                          False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Columns: 111 entries, id to total_il_high_credit_limit
# dtypes: float64(74), int64(13), object(24)
# memory usage: 33.6+ MB

# %%
#df.iloc[:,df.isnull().sum()==39717]

# %%
np.array(df.isnull().sum()==39717)
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True, False, False,  True,
#         True,  True, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False, False,  True,
#         True,  True,  True])

# %%
df1=df.iloc[:,np.array(df.isnull().sum()<39717)]

# %%
df1.shape
# Out:
# (39717, 57)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 57 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          39717 non-null  int64
#  1   member_id                   39717 non-null  int64
#  2   loan_amnt                   39717 non-null  int64
#  3   funded_amnt                 39717 non-null  int64
#  4   funded_amnt_inv             39717 non-null  float64
#  5   term                        39717 non-null  object
#  6   int_rate                    39717 non-null  object
#  7   installment                 39717 non-null  float64
#  8   grade                       39717 non-null  object
#  9   sub_grade                   39717 non-null  object
#  10  emp_title                   37258 non-null  object
#  11  emp_length                  38642 non-null  object
#  12  home_ownership              39717 non-null  object
# ...

# %%
df1.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
# term                              0
# int_rate                          0
# installment                       0
# grade                             0
# sub_grade                         0
# emp_title                      2459
# emp_length                     1075
# home_ownership                    0
# annual_inc                        0
# verification_status               0
# issue_d                           0
# loan_status                       0
# pymnt_plan                        0
# url                               0
# desc                          12940
# purpose                           0
# title                            11
# zip_code                          0
# addr_state                        0
# dti                               0
# delinq_2yrs                       0
# ...

# %%
df1.sample(10)
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade                        emp_title emp_length home_ownership  annual_inc verification_status issue_d  loan_status pymnt_plan                                                url                                               desc             purpose                              title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  policy_code application_type  acc_now_delinq  chargeoff_within_12_mths  delinq_amnt  pub_rec_bankruptcies  tax_liens
# ...

# %% [markdown]
# Removing some columns which are not at all changing or not necesaary
#
# Observation - Can it be based on a zipcode
# can the deliquency be checked with salary to liability ratio?
# can it be checked for multiple bank accounts
# Can Employment length be a factor ?

# %%
df1.describe(include='all')
# Out:
#                   id     member_id     loan_amnt   funded_amnt  funded_amnt_inv        term int_rate   installment  grade sub_grade emp_title emp_length home_ownership    annual_inc verification_status issue_d loan_status pymnt_plan                                                url   desc             purpose               title zip_code addr_state           dti   delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record      open_acc       pub_rec      revol_bal revol_util     total_acc initial_list_status     out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  policy_code application_type  acc_now_delinq  chargeoff_within_12_mths  delinq_amnt  pub_rec_bankruptcies  tax_liens
# ...

# %% [markdown]
# Also, we have to analyse what parameters make a candidate good for taking loan

# %%
df1[df1.isnull().sum(axis=1)>7]
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade emp_title emp_length home_ownership  annual_inc verification_status issue_d loan_status pymnt_plan                                                url                                               desc purpose                           title zip_code addr_state   dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  collections_12_mths_ex_med  policy_code application_type  acc_now_delinq  chargeoff_within_12_mths  delinq_amnt  pub_rec_bankruptcies  tax_liens
# ...

# %%
df1=df1.drop('emp_title',axis=1)
df1=df1.drop('pymnt_plan',axis=1)
df1=df1.drop('url',axis=1)
df1=df1.drop('desc',axis=1)
df1=df1.drop('initial_list_status',axis=1)
df1=df1.drop('next_pymnt_d',axis=1)
df1=df1.drop('policy_code',axis=1)
df1=df1.drop('application_type',axis=1)
df1=df1.drop('acc_now_delinq',axis=1)
df1=df1.drop('tax_liens',axis=1)
df1=df1.drop('delinq_amnt',axis=1)
df1=df1.drop('chargeoff_within_12_mths',axis=1)
df1=df1.drop('collections_12_mths_ex_med',axis=1)

# %%
df1.shape
# Out:
# (39717, 44)

# %%
#df1[df1.collections_12_mths_ex_med=='NA']

# %%
df1.describe(include='all')
# Out:
#                   id     member_id     loan_amnt   funded_amnt  funded_amnt_inv        term int_rate   installment  grade sub_grade emp_length home_ownership    annual_inc verification_status issue_d loan_status             purpose               title zip_code addr_state           dti   delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record      open_acc       pub_rec      revol_bal revol_util     total_acc     out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  pub_rec_bankruptcies
# ...

# %%
df1.zip_code.value_counts()
# Out:
# 100xx    597
# 945xx    545
# 112xx    516
# 606xx    503
# 070xx    473
#         ...
# 736xx      1
# 353xx      1
# 169xx      1
# 833xx      1
# 375xx      1
# Name: zip_code, Length: 823, dtype: int64

# %%
df1.addr_state.value_counts()
# Out:
# CA    7099
# NY    3812
# FL    2866
# TX    2727
# NJ    1850
# IL    1525
# PA    1517
# VA    1407
# GA    1398
# MA    1340
# OH    1223
# MD    1049
# AZ     879
# WA     840
# CO     792
# NC     788
# CT     751
# MI     720
# MO     686
# MN     615
# NV     497
# SC     472
# WI     460
# AL     452
# OR     451
# LA     436
# KY     325
# OK     299
# KS     271
# UT     258
# AR     245
# DC     214
# RI     198
# NM     189
# WV     177
# HI     174
# NH     171
# DE     114
# MT      85
# WY      83
# AK      80
# SD      64
# VT      54
# MS      19
# TN      17
# IN       9
# ID       6
# IA       5
# NE       5
# ME       3
# Name: addr_state, dtype: int64

# %%
df1.purpose.value_counts().plot.bar()

# %%
df1.term.value_counts()
# Out:
#  36 months    29096
#  60 months    10621
# Name: term, dtype: int64

# %%
df1.grade.value_counts(normalize=True).plot.bar()

# %%
df1.sub_grade.value_counts()
# Out:
# B3    2917
# A4    2886
# A5    2742
# B5    2704
# B4    2512
# C1    2136
# B2    2057
# C2    2011
# B1    1830
# A3    1810
# C3    1529
# A2    1508
# D2    1348
# C4    1236
# C5    1186
# D3    1173
# A1    1139
# D4     981
# D1     931
# D5     874
# E1     763
# E2     656
# E3     553
# E4     454
# E5     416
# F1     329
# F2     249
# F3     185
# F4     168
# F5     118
# G1     104
# G2      78
# G4      56
# G3      48
# G5      30
# Name: sub_grade, dtype: int64

# %%
df1.emp_length.value_counts().plot.bar()

# %%
df1.home_ownership.value_counts().plot.bar()

# %%
df1.annual_inc.plot.box()

# %% [markdown]
# there are some outliers in annual income , we need to clean those data

# %%
df1.verification_status.value_counts().plot.bar()

# %% [markdown]
# ### Annual Income we need to  bucketed so that we can plot some graphs

# %% [markdown]
# ## We need to bucket the issue year and say that which year we had max defaults

# %%
df1.issue_d.value_counts()
# Out:
# Dec-11    2260
# Nov-11    2223
# Oct-11    2114
# Sep-11    2063
# Aug-11    1928
# Jul-11    1870
# Jun-11    1827
# May-11    1689
# Apr-11    1562
# Mar-11    1443
# Jan-11    1380
# Feb-11    1297
# Dec-10    1267
# Oct-10    1132
# Nov-10    1121
# Jul-10    1119
# Sep-10    1086
# Aug-10    1078
# Jun-10    1029
# May-10     920
# Apr-10     827
# Mar-10     737
# Feb-10     627
# Nov-09     602
# Dec-09     598
# Jan-10     589
# Oct-09     545
# Sep-09     449
# Aug-09     408
# Jul-09     374
# Jun-09     356
# May-09     319
# Apr-09     290
# Mar-09     276
# Feb-09     260
# Jan-09     239
# Mar-08     236
# Dec-08     223
# Nov-08     184
# Feb-08     174
# Jan-08     171
# Apr-08     155
# Oct-08      96
# Dec-07      85
# Jul-08      83
# May-08      71
# Aug-08      71
# Jun-08      66
# Oct-07      47
# Nov-07      37
# Aug-07      33
# Sep-08      32
# Jul-07      30
# Sep-07      18
# Jun-07       1
# Name: issue_d, dtype: int64

# %%
df1.loan_status.value_counts().plot.bar()

# %% [markdown]
# ## loan amount also should be bucketed or analysis

# %% [markdown]
# ## I want to check the relation between loan status VS verification_status and loan_status VS home_ownership

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(x='loan_status',y='loan_amnt',data=df1)

# %%
sns.boxplot(x='verification_status',y='loan_amnt',data=df1)

# %%
#sns.boxplot(x='annual_inc',y='loan_amnt',data=df1)

# %%
sns.boxplot(x='home_ownership',y='loan_amnt',data=df1)

# %%
sns.boxplot(x='emp_length',y='loan_amnt',data=df1)

# %%
df1.head(5)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade emp_length home_ownership  annual_inc verification_status issue_d  loan_status         purpose                 title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  pub_rec_bankruptcies
# ...

# %%
sns.boxplot(x='term',y='loan_amnt',data=df1)

# %%
sns.boxplot(x='grade',y='loan_amnt',data=df1)

# %%
df1.groupby('home_ownership')['loan_status'].value_counts()
# Out:
# home_ownership  loan_status
# MORTGAGE        Fully Paid     14694
#                 Charged Off     2327
#                 Current          638
# NONE            Fully Paid         3
# OTHER           Fully Paid        80
#                 Charged Off       18
# OWN             Fully Paid      2532
#                 Charged Off      443
#                 Current           83
# RENT            Fully Paid     15641
#                 Charged Off     2839
#                 Current          419
# Name: loan_status, dtype: int64

# %%
df1.groupby('home_ownership')['loan_status'].value_counts().plot.bar()

# %% [markdown]
# ### We can see charged off is max when we have Rent

# %%
df1.groupby('term')['loan_status'].value_counts().plot.bar()

# %%
df1.groupby('loan_status')['term'].value_counts().plot.bar()

# %%
df1.groupby('loan_status')['loan_amnt'].value_counts()
# Out:
# loan_status  loan_amnt
# Charged Off  10000        362
#              12000        303
#              5000         287
#              15000        259
#              25000        252
#                          ...
# Fully Paid   33425          1
#              33500          1
#              34200          1
#              34525          1
#              34675          1
# Name: loan_amnt, Length: 1584, dtype: int64

# %% [markdown]
# ### We won't be able to show the relation until unless we group it in some groups

# %%
df1.groupby('loan_status')['grade'].value_counts().plot.bar()

# %%
df1.grade.value_counts()
# Out:
# B    12020
# A    10085
# C     8098
# D     5307
# E     2842
# F     1049
# G      316
# Name: grade, dtype: int64

# %%
df1.groupby('loan_status')['grade'].value_counts()
# Out:
# loan_status  grade
# Charged Off  B         1425
#              C         1347
#              D         1118
#              E          715
#              A          602
#              F          319
#              G          101
# Current      B          345
#              C          264
#              D          222
#              E          179
#              F           73
#              A           40
#              G           17
# Fully Paid   B        10250
#              A         9443
#              C         6487
#              D         3967
#              E         1948
#              F          657
#              G          198
# Name: grade, dtype: int64

# %%
df1.groupby('loan_status')['emp_length'].value_counts().plot.bar()

# %%
df1.groupby('loan_status')['verification_status'].value_counts().plot.bar()

# %% [markdown]
# ### We can see that the not verified are the most vulnerable loans

# %%
df1.groupby('loan_status')['issue_d'].value_counts()
# Out:
# loan_status  issue_d
# Charged Off  Dec-11      423
#              Nov-11      335
#              Oct-11      308
#              Sep-11      307
#              May-11      289
#              Jul-11      278
#              Aug-11      267
#              Jun-11      267
#              Apr-11      221
#              Mar-11      207
#              Jan-11      186
#              Sep-10      175
#              Feb-11      168
#              Jun-10      166
#              Oct-10      160
#              Aug-10      148
#              Dec-10      142
#              Nov-10      142
#              Jul-10      137
#              May-10      125
#              Oct-09       87
#              Nov-09       83
#              Apr-10       82
#              Jan-10       76
#              Mar-10       69
#              Feb-10       63
#              Dec-09       62
#              Sep-09       57
#              Jul-09       47
#              Jun-09       43
#              May-09       42
# ...

# %%
df_charged_off=df1[df1.loan_status=='Charged Off']

# %%
df_charged_off.head(5)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade emp_length home_ownership  annual_inc verification_status issue_d  loan_status             purpose                                 title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  pub_rec_bankruptcies
# ...

# %%
df_fully_paid=df1[df1.loan_status=='Fully Paid']

# %%
df_fully_paid.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade emp_length home_ownership  annual_inc verification_status issue_d loan_status             purpose                                  title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  pub_rec_bankruptcies
# ...

# %%
df_charged_off.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5627 entries, 1 to 39688
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       5627 non-null   int64
#  1   member_id                5627 non-null   int64
#  2   loan_amnt                5627 non-null   int64
#  3   funded_amnt              5627 non-null   int64
#  4   funded_amnt_inv          5627 non-null   float64
#  5   term                     5627 non-null   object
#  6   int_rate                 5627 non-null   object
#  7   installment              5627 non-null   float64
#  8   grade                    5627 non-null   object
#  9   sub_grade                5627 non-null   object
#  10  emp_length               5399 non-null   object
#  11  home_ownership           5627 non-null   object
#  12  annual_inc               5627 non-null   float64
#  13  verification_status      5627 non-null   object
# ...

# %%
df_charged_off.isnull().sum()
# Out:
# id                            0
# member_id                     0
# loan_amnt                     0
# funded_amnt                   0
# funded_amnt_inv               0
# term                          0
# int_rate                      0
# installment                   0
# grade                         0
# sub_grade                     0
# emp_length                  228
# home_ownership                0
# annual_inc                    0
# verification_status           0
# issue_d                       0
# loan_status                   0
# purpose                       0
# title                         2
# zip_code                      0
# addr_state                    0
# dti                           0
# delinq_2yrs                   0
# earliest_cr_line              0
# inq_last_6mths                0
# mths_since_last_delinq     3485
# mths_since_last_record     5049
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# ...

# %%
df_charged_off.shape
# Out:
# (5627, 44)

# %%
df_charged_off.int_rate.value_counts()
# Out:
# 13.49%    127
# 11.49%    127
# 10.99%     95
# 11.71%     91
# 11.99%     76
# 14.27%     74
# 12.69%     72
# 16.77%     71
# 12.99%     69
# 18.25%     62
# 16.49%     61
# 17.49%     59
# 15.99%     59
# 9.99%      58
# 16.89%     57
# 13.99%     56
# 12.42%     55
# 11.86%     55
# 17.27%     54
# 7.51%      54
# 15.27%     52
# 10.37%     51
# 8.49%      49
# 7.90%      49
# 10.59%     47
# 13.98%     46
# 10.65%     46
# 15.21%     45
# 16.45%     45
# 12.53%     44
# 12.68%     44
# 16.32%     44
# 15.23%     42
# 15.58%     42
# 17.58%     41
# 14.79%     41
# 14.65%     41
# 17.99%     40
# 18.64%     40
# 9.63%      40
# 18.39%     40
# 7.49%      39
# 7.88%      38
# 15.65%     38
# 16.40%     38
# 13.23%     37
# 13.61%     37
# 14.91%     36
# 11.11%     36
# 19.03%     36
# 8.90%      36
# 12.61%     35
# 15.95%     35
# 9.91%      35
# 13.06%     34
# 16.02%     34
# 15.96%     33
# 10.74%     33
# 13.43%     33
# 16.29%     33
# 10.36%     32
# 19.91%     32
# ...

# %%
df1.pub_rec_bankruptcies.value_counts()
# Out:
# 0.0    37339
# 1.0     1674
# 2.0        7
# Name: pub_rec_bankruptcies, dtype: int64

# %%
df_charged_off.pub_rec_bankruptcies.value_counts()
# Out:
# 0.0    5141
# 1.0     366
# 2.0       2
# Name: pub_rec_bankruptcies, dtype: int64

# %%
df1.groupby('loan_status')['pub_rec_bankruptcies'].value_counts()
# Out:
# loan_status  pub_rec_bankruptcies
# Charged Off  0.0                      5141
#              1.0                       366
#              2.0                         2
# Current      0.0                      1101
#              1.0                        37
#              2.0                         2
# Fully Paid   0.0                     31097
#              1.0                      1271
#              2.0                         3
# Name: pub_rec_bankruptcies, dtype: int64

# %%
df1.groupby('loan_status')['pub_rec_bankruptcies'].value_counts().plot.bar()

# %%
df1.open_acc.value_counts()
# Out:
# 7     4018
# 6     3946
# 8     3936
# 9     3718
# 10    3223
# 5     3183
# 11    2746
# 4     2343
# 12    2273
# 13    1911
# 3     1493
# 14    1487
# 15    1177
# 16     940
# 17     741
# 2      605
# 18     533
# 19     396
# 20     289
# 21     244
# 22     143
# 23      97
# 24      81
# 25      55
# 26      34
# 28      25
# 27      22
# 30      15
# 29      13
# 31       7
# 34       5
# 35       4
# 32       4
# 33       3
# 36       2
# 38       1
# 39       1
# 41       1
# 42       1
# 44       1
# Name: open_acc, dtype: int64

# %%
df_charged_off.open_acc.value_counts()
# Out:
# 7     557
# 8     546
# 6     543
# 9     518
# 10    465
# 5     425
# 11    382
# 4     364
# 12    301
# 13    263
# 3     258
# 14    217
# 15    168
# 2     127
# 16    105
# 17    102
# 18     68
# 19     59
# 20     42
# 21     37
# 22     18
# 23     12
# 25     11
# 24      9
# 26      7
# 27      6
# 28      5
# 31      3
# 30      3
# 33      2
# 38      1
# 29      1
# 34      1
# 35      1
# Name: open_acc, dtype: int64

# %%
df_charged_off.describe(include='all')
# Out:
#                   id     member_id     loan_amnt   funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade emp_length home_ownership    annual_inc verification_status issue_d  loan_status             purpose               title zip_code addr_state          dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record     open_acc      pub_rec      revol_bal revol_util    total_acc  out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  pub_rec_bankruptcies
# ...

# %%
df_charged_off
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade emp_length home_ownership  annual_inc verification_status issue_d  loan_status             purpose                                 title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  pub_rec_bankruptcies
# ...

# %%
df_charged_off.int_rate= df_charged_off.int_rate.apply(lambda x: float(x[:-1]))
# Out:
# /Users/290020828/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_charged_off.describe(include='all').transpose()
# Out:
#                         count unique                 top  freq       mean       std    min      25%      50%          75%          max
# id                       5627    NaN                 NaN   NaN     697844    216377  61419   529724   696937       854876  1.07743e+06
# member_id                5627    NaN                 NaN   NaN     867752    272327  80353   684905   888158  1.06658e+06  1.31417e+06
# loan_amnt                5627    NaN                 NaN   NaN    12104.4   8085.73    900     5600    10000        16500        35000
# funded_amnt              5627    NaN                 NaN   NaN    11753.4   7760.52    900     5575    10000        16000        35000
# funded_amnt_inv          5627    NaN                 NaN   NaN    10864.5   7661.75      0     5000  9401.21        15000        35000
# term                     5627      2           36 months  3227        NaN       NaN    NaN      NaN      NaN          NaN          NaN
# ...

# %%
df_charged_off.int_rate.plot.box()

# %%
df_charged_off.home_ownership.value_counts(normalize=True).plot.bar()

# %%
df_charged_off.term.value_counts(normalize=True)*100
# Out:
#  36 months    57.348498
#  60 months    42.651502
# Name: term, dtype: float64

# %%
df_charged_off['int_bucket']=pd.qcut(df_charged_off.int_rate,[0,5,10,15,20,25],[5,10,15,20,25])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-112-a0e7c6396856> in <module>
# ----> 1 df_charged_off['int_bucket']=pd.qcut(df_charged_off.int_rate,[0,5,10,15,20,25],[5,10,15,20,25])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/tile.py in qcut(x, q, labels, retbins, precision, duplicates)
#     338     else:
#     339         quantiles = q
# --> 340     bins = algos.quantile(x, quantiles)
#     341     fac, bins = _bins_to_cuts(
#     342         x,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/algorithms.py in quantile(x, q, interpolation_method)
#    1061     else:
#    1062         q = np.asarray(q, np.float64)
# -> 1063         result = [_get_score(x) for x in q]
#    1064         result = np.array(result, dtype=np.float64)
#    1065         return result
#
# ...

# %%
result=pd.pivot_table(data=df1,index="loan_status",columns="home_ownership",values="loan_amnt")

# %%
import seaborn as sns

# %%
sns.heatmap(result)

# %%
result1=pd.pivot_table(data=df1,index="loan_status",columns="grade",values="loan_amnt")
sns.heatmap(result1)

# %%
result1=pd.pivot_table(data=df1,index="loan_status",columns="verification_status",values="loan_amnt")
sns.heatmap(result1)

# %%
result1=pd.pivot_table(data=df1,index="loan_status",columns="int_rate",values="loan_amnt")
sns.heatmap(result1)

# %% [markdown]
# 1) check if funded amunt is greater than applied amount
# 2) funding-amy-inv > fundng_amt

# %%
sns.barplot(x=df1.term,y=df1.loan_status)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-8d7b07de93d6> in <module>
# ----> 1 sns.barplot(x=df1.term,y=df1.loan_status)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3142             ax=None, **kwargs):
#    3143
# -> 3144     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3145                           estimator, ci, n_boot, units, seed,
#    3146                           orient, color, palette, saturation,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %%
sns.distplot(df1.loan_amnt)

# %%
df1.loan_amnt.describe()
# Out:
# count    39717.000000
# mean     11219.443815
# std       7456.670694
# min        500.000000
# 25%       5500.000000
# 50%      10000.000000
# 75%      15000.000000
# max      35000.000000
# Name: loan_amnt, dtype: float64

# %%
df1[df1.loan_amnt>15000]
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment grade sub_grade emp_length home_ownership  annual_inc verification_status issue_d  loan_status             purpose                                 title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  pub_rec_bankruptcies
# ...

# %%
df_charged_off['int_bucket']=pd.cut(df_charged_off.int_rate,bins=[0,5,10,15,20,30],labels=["Very Low Interest","Low Interest","Moderate Interest","High Interest","Very High Interest"])
# Out:
# <ipython-input-126-e05ed8a59c8a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_charged_off['int_bucket']=pd.cut(df_charged_off.int_rate,bins=[0,5,10,15,20,30],labels=["Very Low Interest","Low Interest","Moderate Interest","High Interest","Very High Interest"])

# %%
df_charged_off.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment grade sub_grade emp_length home_ownership  annual_inc verification_status issue_d  loan_status             purpose                                 title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  pub_rec_bankruptcies         int_bucket
# ...

# %%
df_charged_off.loan_status= df_charged_off.loan_status.apply(lambda x: 1 if x=='Charged Off' else 0)
# Out:
# /Users/290020828/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
sns.barplot(x=df_charged_off.int_bucket, y=df_charged_off.loan_status)

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
df1.describe(include='all').transpose()
# Out:
#                          count unique                 top   freq       mean       std    min      25%      50%          75%          max
# id                       39717    NaN                 NaN    NaN     683132    210694  54734   516221   665665       837755   1.0775e+06
# member_id                39717    NaN                 NaN    NaN     850464    265678  70699   666780   850812  1.04734e+06  1.31417e+06
# loan_amnt                39717    NaN                 NaN    NaN    11219.4   7456.67    500     5500    10000        15000        35000
# funded_amnt              39717    NaN                 NaN    NaN    10947.7   7187.24    500     5400     9600        15000        35000
# funded_amnt_inv          39717    NaN                 NaN    NaN    10397.4   7128.45      0     5000     8975        14400        35000
# term                     39717      2           36 months  29096        NaN       NaN    NaN      NaN      NaN          NaN          NaN
# ...

# %%
plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  <a list of 6 Text major ticklabel objects>)

# %%
df_charged_off[df_charged_off.addr_state=='ID']
# Out:
#            id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment grade sub_grade emp_length home_ownership  annual_inc verification_status issue_d  loan_status      purpose                          title zip_code addr_state    dti  delinq_2yrs earliest_cr_line  inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  pub_rec  revol_bal revol_util  total_acc  out_prncp  out_prncp_inv  total_pymnt  total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt last_credit_pull_d  pub_rec_bankruptcies         int_bucket
# ...
